# %%
# Load OpenAI API key
import gradio as gr
import os
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv()

client = OpenAI(
    api_key=os.getenv("OPENAI_API_KEY"),  # This is the default and can be omitted
)

# %%
# Method to generate image using DALL-E 3 model
def generate_image_dalle3(prompt):
    response = client.images.generate(
      prompt=prompt,
      model="dall-e-3",
      n=1,
      size="1024x1024"
    )
    print(response)
    image_url = response.data[0].url
    revised_prompt = response.data[0].revised_prompt
    return image_url,revised_prompt

# %%
# Display image and revised prompt 
import gradio as gr
with gr.Blocks() as demo:
    title = gr.HTML("<h1>AI Image Generator with DALL-E 3</h1>")
    gr.Markdown("Enter your prompt and then click **Submit** to generate the image.")
    with gr.Row(equal_height=True):
        inp = gr.Textbox(label="Prompt",placeholder="Enter your Prompt")
    with gr.Row(equal_height=True):
        img_out = gr.Image(label= "AI Generated Image")
        revised_out = gr.Textbox(label="Prompt suggestion by DALL E-3")
    btn = gr.Button("Submit")
    btn.click(fn=generate_image_dalle3, inputs=inp, outputs=[img_out,revised_out])
demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7868
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7868/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
